# %%
import numpy as np
import seaborn as sns

# %% [markdown]
# # Markdown Title
# ## double down
# ### triple down
# #### quadrapule down
# #### 1. better
#      2. much better

# %%
x = np.array([1,2,3,3,3,4,5,6,7,8,9,1,1,2,3,4,5])

# %%
sns.distplot(x)
